# %%
json1 = """{
    "code":0,
    "desc":"成功",
    "data":{
        "id":114,
        "templateCode":"AUDIO20200901",
        "templateName":"语音上线测试",
        "templateType":"AUDIO",
        "createUserId":"W9007768",
        "createUserName":"谢梦诗",
        "updateUserId":"W9007768",
        "updateUserName":"谢梦诗",
        "createTime":"2020-09-01 19:46:18",
        "updateTime":"2020-09-01 21:50:12",
        "templateBody":{
            "column1":[
                {
                    "componentType":"form",
                    "bindTypes":[
                        "item",
                        "clip"
                    ],
                    "data":[
                        {
                            "code":"(MUSIC)",
                            "keyCodes":[
                                "ALT",
                                "M"
                            ],
                            "id":"default",
                            "desc":"音乐"
                        },
                        {
                            "code":"001",
                            "keyCodes":[
                                "ALT",
                                "Z"
                            ],
                            "id":"5d88765d-b52e-4e19-9c16-e17f6c0035b2",
                            "desc":"001"
                        },
                        {
                            "code":"002",
                            "keyCodes":[
                                "ALT",
                                "A"
                            ],
                            "id":"0b47ab04-b043-4ffd-b72d-84491ef371dc",
                            "desc":"002"
                        },
                        {
                            "code":"003",
                            "keyCodes":[
                                "ALT",
                                "Q"
                            ],
                            "id":"c69d043b-3d8c-4758-93ef-047869c46cdd",
                            "desc":"003"
                        },
                        {
                            "code":"004",
                            "keyCodes":[
                                "ALT",
                                "X"
                            ],
                            "id":"e66ba03a-b114-49f7-b503-9bb0f73d41c4",
                            "desc":"004"
                        }
                    ],
                    "header":"快捷字符",
                    "id":"de65af3a-8436-40a1-a405-24f2bf92d1dc",
                    "type":"shortcut-character",
                    "tips":""
                },
                {
                    "val":"",
                    "componentType":"form",
                    "maxRows":5,
                    "bindTypes":[
                        "item"
                    ],
                    "header":"文本框",
                    "id":"47b92d2a-8819-42b0-b689-efc193414d95","type":"multi-input",
                    "tips":"",
                    "required":false
                }
            ],
            "column0":[
                {
                    "id":"9e068d8a-2805-464b-9bec-30eb23dc90d8",
                    "type":"audio-file-placeholder"
                },
                {
                    "val":[

                    ],
                    "componentType":"form",
                    "data":[
                        {
                            "checked":false,
                            "text":"Option1"
                        },
                        {
                            "checked":false,
                            "text":"Option2"
                        }
                    ],
                    "bindTypes":[
                        "item"
                    ],
                    "multiple":false,
                    "header":"选择框",
                    "id":"fbceb795-dd08-4c32-9fcb-484053ad3e6a","type":"checkbox",
                    "tips":"",
                    "required":true
                }
            ],
            "id":"c3840371-4bae-4cc3-a564-a6c845694ea8"
        },
        "delete":false
    }
}"""

json2 = """
{
    "code":0,
    "desc":"成功",
    "data":{
        "id":114,
        "templateCode":"AUDIO20200901",
        "templateName":"语音上线测试",
        "templateType":"AUDIO",
        "createUserId":"W9007768",
        "createUserName":"谢梦诗",
        "updateUserId":"W9007768",
        "updateUserName":"谢梦诗",
        "createTime":"2020-09-01 19:46:18",
        "updateTime":"2020-09-01 21:50:12",
        "templateBody":{
            "column1":[
                {
                    "componentType":"form",
                    "bindTypes":[
                        "item",
                        "clip"
                    ],
                    "data":[
                        {
                            "code":"(MUSIC)",
                            "keyCodes":[
                                "ALT",
                                "M"
                            ],
                            "id":"default",
                            "desc":"音乐"
                        },
                        {
                            "code":"001",
                            "keyCodes":[
                                "ALT",
                                "Z"
                            ],
                            "id":"5d88765d-b52e-4e19-9c16-e17f6c0035b2",
                            "desc":"001"
                        },
                        {
                            "code":"002",
                            "keyCodes":[
                                "ALT",
                                "A"
                            ],
                            "id":"0b47ab04-b043-4ffd-b72d-84491ef371dc",
                            "desc":"002"
                        },
                        {
                            "code":"003",
                            "keyCodes":[
                                "ALT",
                                "Q"
                            ],
                            "id":"c69d043b-3d8c-4758-93ef-047869c46cdd",
                            "desc":"003"
                        },
                        {
                            "code":"004",
                            "keyCodes":[
                                "ALT",
                                "X"
                            ],
                            "id":"e66ba03a-b114-49f7-b503-9bb0f73d41c4",
                            "desc":"004"
                        }
                    ],
                    "header":"快捷字符",
                    "id":"de65af3a-8436-40a1-a405-24f2bf92d1dc",
                    "type":"shortcut-character",
                    "tips":""
                },
                {
                    "val":"",
                    "componentType":"form",
                    "maxRows":5,
                    "bindTypes":[
                        "item"
                    ],
                    "header":"文本框",
                    "id":"47b92d2a-8819-42b0-b689-efc193414d95","type":"multi-input",
                    "tips":"",
                    "required":false
                },
                {
                    "val":"",
                    "componentType":"form",
                    "maxRows":5,
                    "bindTypes":[
                        "item"
                    ],
                    "header":"文本框",
                    "id":"47b92d2a-8819-42b0-b689-efc193414d95","type":"multi-input",
                    "tips":"",
                    "required":false
                }
            ],
            "column0":[
                {
                    "id":"9e068d8a-2805-464b-9bec-30eb23dc90d8",
                    "type":"audio-file-placeholder"
                },
                {
                    "val":[

                    ],
                    "componentType":"form",
                    "data":[
                        {
                            "checked":false,
                            "text":"Option1"
                        },
                        {
                            "checked":false,
                            "text":"Option2"
                        }
                    ],
                    "bindTypes":[
                        "item"
                    ],
                    "multiple":false,
                    "header":"选择框",
                    "id":"fbceb795-dd08-4c32-9fcb-484053ad3e6a","type":"checkbox",
                    "tips":"",
                    "required":true
                }
            ],
            "id":"c3840371-4bae-4cc3-a564-a6c845694ea8"
        },
        "delete":false
    }
}"""

# %%
import json

# %%
form_components = []
form_component_multi_inputs = []
def load_json_text(json_text):
    form_components.clear()
    columns_dict = json.loads(json_text)['data']['templateBody']
    for k, column in columns_dict.items():
        if k.startswith('column'):
            form_components.extend(column)
    form_component_multi_inputs.clear()
    for form_component in form_components:
        if 'type' in form_component and form_component['type'] == 'multi-input':
            form_component_multi_inputs.append(form_component)


load_json_text(json1)
form_component_multi_inputs
# Out:
# [{'val': '',
#   'componentType': 'form',
#   'maxRows': 5,
#   'bindTypes': ['item'],
#   'header': '文本框',
#   'id': '47b92d2a-8819-42b0-b689-efc193414d95',
#   'type': 'multi-input',
#   'tips': '',
#   'required': False}]

# %%
import pandas as pd

xlsx = pd.ExcelFile("test.xlsx")

# %%
df1 = pd.read_excel(xlsx, sheet_name=0)
df2 = pd.read_excel(xlsx, sheet_name=1)
display(df1)
display(df2)
# Out:
#    recordid query  result
# 0         1    张三     NaN
# 1         2    李四     NaN
# 2         3    王八     NaN
#    recordid query1   query2  result
# 0         1     张三  大幅降低身份卡     NaN
# 1         2     李四  范德萨和复活节     NaN

# %%
def result_process(df):
    results = []
    columns = [column for column in df.columns if column.find('query') != -1]
    print(columns)
    for row in df[columns].values:
        for i in range(len(row)):
            form_component_multi_inputs[i]['val'] = row[i]
        display(form_component_multi_inputs)
        results.append(json.dumps(form_components, ensure_ascii=False, indent=2))
    df['result'] = results

# %%
load_json_text(json1)
result_process(df1)
df1
# Out:
# ['query']
# [{'val': '张三',
#   'componentType': 'form',
#   'maxRows': 5,
#   'bindTypes': ['item'],
#   'header': '文本框',
#   'id': '47b92d2a-8819-42b0-b689-efc193414d95',
#   'type': 'multi-input',
#   'tips': '',
#   'required': False}]
# [{'val': '李四',
#   'componentType': 'form',
#   'maxRows': 5,
#   'bindTypes': ['item'],
#   'header': '文本框',
#   'id': '47b92d2a-8819-42b0-b689-efc193414d95',
#   'type': 'multi-input',
#   'tips': '',
#   'required': False}]
# [{'val': '王八',
#   'componentType': 'form',
#   'maxRows': 5,
#   'bindTypes': ['item'],
#   'header': '文本框',
#   'id': '47b92d2a-8819-42b0-b689-efc193414d95',
#   'type': 'multi-input',
#   'tips': '',
#   'required': False}]
#    recordid query                                             result
# 0         1    张三  [\n  {\n    "componentType": "form",\n    "bin...
# 1         2    李四  [\n  {\n    "componentType": "form",\n    "bin...
# 2         3    王八  [\n  {\n    "componentType": "form",\n    "bin...

# %%
load_json_text(json2)
result_process(df2)
df2
# Out:
# ['query1', 'query2']
# [{'val': '张三',
#   'componentType': 'form',
#   'maxRows': 5,
#   'bindTypes': ['item'],
#   'header': '文本框',
#   'id': '47b92d2a-8819-42b0-b689-efc193414d95',
#   'type': 'multi-input',
#   'tips': '',
#   'required': False},
#  {'val': '大幅降低身份卡',
#   'componentType': 'form',
#   'maxRows': 5,
#   'bindTypes': ['item'],
#   'header': '文本框',
#   'id': '47b92d2a-8819-42b0-b689-efc193414d95',
#   'type': 'multi-input',
#   'tips': '',
#   'required': False}]
# [{'val': '李四',
#   'componentType': 'form',
#   'maxRows': 5,
#   'bindTypes': ['item'],
#   'header': '文本框',
#   'id': '47b92d2a-8819-42b0-b689-efc193414d95',
#   'type': 'multi-input',
#   'tips': '',
#   'required': False},
#  {'val': '范德萨和复活节',
#   'componentType': 'form',
#   'maxRows': 5,
#   'bindTypes': ['item'],
#   'header': '文本框',
#   'id': '47b92d2a-8819-42b0-b689-efc193414d95',
#   'type': 'multi-input',
#   'tips': '',
#   'required': False}]
# ...

# %%
# result_xlsx = pd.ExcelWriter(r"F:\360MoveData\Users\Administrator\Desktop\result.xlsx")
df1.to_excel(r"F:\360MoveData\Users\Administrator\Desktop\result.xlsx", "n1")
df2.to_excel(r"F:\360MoveData\Users\Administrator\Desktop\result1.xlsx", "n2")
